# %%
# !nvidia-smi
# Out:
# Sat Mar 21 05:44:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install "ultralytics" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.24 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.7/112.6 GB disk)

# %%
from ultralytics import YOLO
from PIL import Image
import requests

# %%
import tqdm as notebook_tqdm
from roboflow import Roboflow
import supervision as sv

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
KMP_DUPLICATE_LIB_OK=True

# %%
#TEST

model = YOLO('/content/drive/MyDrive/AZ/yolo11n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWMRE4GC.yaml', batch=16, epochs=1, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# ...
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Create a folder in the root directory
# !mkdir -p "/content/drive/My Drive/AZ/MyResults"

# %%
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPGOODGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.24 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPGOODGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo26n.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPGOODGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# ...
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPGOODGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11m-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/RGBdatasetsSeg/RGBDatasetSegGC.yaml', batch=32, epochs=3, augment=False, imgsz=256, visualize=True, plots=True, cache=True)
# Out:
# ...
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

model.train(data='NIRdatasetNB.yaml', batch=32, epochs=3, augment=False, imgsz=256, visualize=True, plots=True, cache=True)
# Out:
# Ultralytics 8.3.199 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='/content/NIRdatasetNB.yaml', epochs=1, imgsz=640)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSCA17DGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.185 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSON17DGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.185 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWMNIR42GC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.185 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/runs/segment/train3/weights/last.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGREGC.yaml', batch=16, epochs=33, resume=True, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/segment/train6/weights/best.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGREGC.yaml', batch=16, epochs=25, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigCA17DGC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigON17DGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigCA17NDVIGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigON17NDVIGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigHuagGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSFPRENIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWMNIR4GC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWMRE4GC.yaml', batch=16, epochs=30, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWMNDVI2GC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSB16GC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGREGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGNIRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigSB16Multi150.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigTSFDGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGRGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGGGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/AZ/yolo11l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/AZ/Yaml2/segconfigWGBGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)

# %%
model = YOLO('/content/drive/MyDrive/yolo11n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/segconfigWGREGC.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('yolo11m-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfigWMRE.yaml', batch=4, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11m-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('last.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', epochs=15, resume=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11m-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('last.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', epochs=15, resume=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('best.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', epochs=15, resume=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('last.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', epochs=15, resume=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11m-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True, cache=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11s-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='segconfig.yaml', batch=16, epochs=15, augment=False, imgsz=640, visualize=True, plots=True, cache=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

model.train(data='NIRdatasetNB.yaml', batch=32, epochs=3, augment=True, imgsz=256, visualize=True, plots=True, cache=True)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11n.pt data=NIRdatasetNB.yaml epochs=2 imgsz=256 plots=True
# Out:
# C:\Users\PMLS\Downloads
# New https://pypi.org/project/ultralytics/8.3.150 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# train: Scanning C:\Users\PMLS\Desktop\ALL ETC\Downloads\Yolo_Books_Mine\Yolo8_NIR\Ultra\datasets\labels\train.cache... 96 images, 0 backgrounds, 0 corrupt: 100%|##########| 96/96 [00:00<?, ?it/s]
# train: Scanning C:\Users\PMLS\Desktop\ALL ETC\Downloads\Yolo_Books_Mine\Yolo8_NIR\Ultra\datasets\labels\train.cache... 96 images, 0 backgrounds, 0 corrupt: 100%|##########| 96/96 [00:00<?, ?it/s]
# C:\Users\PMLS\anaconda3\Lib\site-packages\ultralytics\data\augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
#
# val: Scanning C:\Users\PMLS\Desktop\ALL ETC\Downloads\Yolo_Books_Mine\Yolo8_NIR\Ultra\datasets\labels\val.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|##########| 30/30 [00:00<?, ?it/s]
# ...
